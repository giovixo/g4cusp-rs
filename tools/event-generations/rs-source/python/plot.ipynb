# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("events.csv")

# %%
df
# Out:
#      event_id      time      angle     pol_x  pol_y     pol_z  energy
# 0           0  0.002087   0.013114  0.999914    0.0  0.013114    30.0
# 1           1  0.016289   0.102344  0.994767    0.0  0.102166    30.0
# 2           2  0.029388   0.184649  0.983001    0.0  0.183602    30.0
# 3           3  0.030525   0.191793  0.981664    0.0  0.190619    30.0
# 4           4  0.040662   0.255490  0.967540    0.0  0.252720    30.0
# ..        ...       ...        ...       ...    ...       ...     ...
# 995       995  9.419396  59.183813 -0.874473    0.0  0.485074    30.0
# 996       996  9.420886  59.193173 -0.878975    0.0  0.476867    30.0
# 997       997  9.439755  59.311731 -0.929209    0.0  0.369555    30.0
# 998       998  9.449133  59.370653 -0.949359    0.0  0.314194    30.0
# 999       999  9.459284  59.434437 -0.967455    0.0  0.253042    30.0
#
# [1000 rows x 7 columns]

# %%
df['time'].plot()
plt.xlabel('Index')  # X-axis label
plt.ylabel('time (s)')  # Y-axis label
plt.title('rate 10 phs/s, exposure 10 s')  # Title

plt.savefig('time.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df.plot.scatter(x='pol_x', y='pol_z', color='blue', marker='.')
plt.savefig('polarization_vector.png', dpi=300, bbox_inches='tight')
plt.show()
